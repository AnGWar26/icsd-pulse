# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
food = pd.read_excel('../data/FOOD_Table4_Week8.xlsx', sheet_name=0, skip_rows=[0,1,2], header=[4], index_col=0,skipfooter=1, nafilter=False, keep_default_na=False)

# %%
food = health.iloc[:, :5]

# %%
food.rename(columns={'Unnamed: 1':'Total(including did not report)'})
# Out:
#                                                    Total(including did not report)  \
#
# Total                                                                    106371747
# Food Sufficiency before Mar 13, 2020
#     Enough of the types of food wanted                                    36120149
#     Enough food, but not always the types wanted                          47751085
#     Sometimes not enough to eat                                           15202552
#     Often not enough to eat                                                2816641
#     Did not report                                                         4481320
# Reason for recent food insufficiency *
#     Couldn’t afford to buy more food                                      49035266
#     Couldn’t get out to buy food                                          14503442
#     Afraid to go or didn’t want to go out to bu...                        27977493
# ...
